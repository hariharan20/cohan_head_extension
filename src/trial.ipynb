# %%
import rospy
from cohan_msgs.msg import TrajectoryStamped
rospy.init_node('adf')
data = rospy.wait_for_message('/move_base/HATebLocalPlannerROS/local_traj' , TrajectoryStamped )

# %%
data
# Out:
# header:
#   seq: 1605
#   stamp:
#     secs: 3115
#     nsecs:  92000000
#   frame_id: "map"
# points:
#   -
#     pose:
#       position:
#         x: 0.6078045726985408
#         y: 2.8458925254030873
#         z: 0.0
#       orientation:
#         x: 0.0
#         y: 0.0
#         z: 0.6284599985565785
#         w: 0.7778419056686682
#     velocity:
#       linear:
#         x: 0.0
#         y: 0.0
#         z: 0.0
#       angular:
#         x: 0.0
#         y: 0.0
#         z: 0.0
#     time_from_start:
#       secs: -1
#       nsecs:         0
#   -
#     pose:
#       position:
#         x: 0.6167691114063416
#         y: 2.88761310707946
#         z: 0.0
#       orientation:
#         x: 0.0
#         y: 0.0
#         z: 0.6411954195363568
#         w: 0.7673776345226615
#     velocity:
#       linear:
#         x: 0.0
#         y: 0.0
#         z: 0.0
#       angular:
#         x: 0.0
#         y: 0.0
#         z: 0.0
#     time_from_start:
#       secs: -1
# ...

# %%
import numpy as np 
len(data.points)
# Out:
# 781

# %%
data_np = np.array(data.points)

# %%
data.points[0]
# Out:
# pose:
#   position:
#     x: 0.6078045726985408
#     y: 2.8458925254030873
#     z: 0.0
#   orientation:
#     x: 0.0
#     y: 0.0
#     z: 0.6284599985565785
#     w: 0.7778419056686682
# velocity:
#   linear:
#     x: 0.0
#     y: 0.0
#     z: 0.0
#   angular:
#     x: 0.0
#     y: 0.0
#     z: 0.0
# time_from_start:
#   secs: -1
#   nsecs:         0

# %%
import ros_numpy
ros_numpy.numpify(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 import ros_numpy
#       2 ros_numpy.numpify(data)
#
# File /opt/ros/noetic/lib/python3/dist-packages/ros_numpy/__init__.py:7
#       5 from .numpy_msg import numpy_msg
#       6 from .registry import numpify, msgify
# ----> 7 from . import point_cloud2
#       8 from . import image
#       9 from . import occupancy_grid
#
# File /opt/ros/noetic/lib/python3/dist-packages/ros_numpy/point_cloud2.py:224
#     221             new_cloud_arr[field_name] = cloud_arr[field_name]
#     222     return new_cloud_arr
# --> 224 def get_xyz_points(cloud_array, remove_nans=True, dtype=np.float):
#     225     '''Pulls out x, y, and z columns from the cloud recordarray, and returns
#     226 	a 3xN matrix.
#     227     '''
#     228     # remove crap points
#
# ...

# %%
data.points[10]

# %%
from geometry_msgs.msg import Pose2D
data = Pose2D(
)
data
# Out:
# x: 0.0
# y: 0.0
# theta: 0.0
